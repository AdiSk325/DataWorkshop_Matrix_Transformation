# %%
import pandas as pd

# %%
cd 'content/drive/My Drive/Colab Notebooks/dw_matrix'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
#mkdir -p 'matrix_three'
cd matrix_three

# %%
#GIT_TOKEN = ''
#GIT_URL = 'https://{0}@github.com/AdiSk325/dw_matrix_road_sign.git'.format(GIT_TOKEN)
#!git clone $GIT_URL
# Out:
# Cloning into 'dw_matrix_road_sign'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.

# %%
cd dw_matrix_road_sign/
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_three/dw_matrix_road_sign

# %%
#!mkdir data
cd data

# %%
#!curl -L http://bit.ly/train_road_sign -o train.p
#!curl -L http://bit.ly/test_road_sign -o test.p
#!curl -L http://bit.ly/dw_signnames -o signnames.csv

# %%
train, test = pd.read_pickle('train.p'), pd.read_pickle('test.p')

# %%
X_train, y_train = train['features'], train['labels']
X_train.shape, y_train.shape
# Out:
# ((34799, 32, 32, 3), (34799,))

# %%
pd.read_csv('signnames.csv').sample(10)
# Out:
#      a                                                  b
# 41  41                                  End of no passing
# 36  36                               Go straight or right
# 23  23                                      Slippery road
# 42  42  End of no passing by vehicles over 3.5 metric ...
# 2    2                               Speed limit (50km/h)
# 34  34                                    Turn left ahead
# 22  22                                         Bumpy road
# 16  16           Vehicles over 3.5 metric tons prohibited
# 11  11              Right-of-way at the next intersection
# 9    9                                         No passing

# %%
# !git add .

# %%
# !git config --global user.email "skutnik.adrian@gmail.com"
# !git config --global user.name "AdiSk325"

# %%
# !git commit -m 'day1 - download data'
# Out:
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Untracked files:
# 	../../day1.ipynb
#
# nothing added to commit but untracked files present

# %%
# !git status
